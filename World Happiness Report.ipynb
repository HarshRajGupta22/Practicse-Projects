# %% [markdown]
# # ..HAPPINESS..

# %% [markdown]
#     What Is Happiness?
#
# Happiness is an emotional state characterized by feelings of joy, satisfaction, contentment, and fulfillment. While happiness has many different definitions, it is often described as involving positive emotions and life satisfaction.
#
#
# When most people talk about happiness, they might be talking about how they feel in the present moment, or they might be referring to a more general sense of how they feel about life overall.
#
# Because happiness tends to be such a broadly defined term, psychologists and other social scientists typically use the term 'subjective well-being' when they talk about this emotional state. Just as it sounds, subjective well-being tends to focus on an individual's overall personal feelings about their life in the present....
#
#
#     Two key components of happiness are:
#
# The balance of emotions: Everyone experiences both positive and negative emotions, feelings, and moods. Happiness is generally linked to experiencing more positive feelings than negative.
# Life satisfaction: This relates to how satisfied you feel with different areas of your life including your relationships, work, achievements, and other things that you consider important.
#
#       Signs of Happiness
#
# While perceptions of happiness may be different from one person to the next, there are some key signs that psychologists look for when measuring and assessing happiness.
#
#
#        Some key signs of happiness include:
#
# *  Feeling like you are living the life you wanted
# *  Feeling that the conditions of your life are good
# *  Feeling that you have accomplished what you want in life
# *  Feeling satisfied with your life
# *  Feeling positive more than negative

# %%
import pandas as pd
import numpy as np
path ='https://raw.githubusercontent.com/shivam229/dsrscientist-DSData/master/happiness_score_dataset.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# # Detail about the columns

# %% [markdown]
#       1. Country
#
#    This column shows the record of happiness among the nationwise with details by categorizing the data..
#
#      2. Region
#
#   It depicts tehe futher classification of the Country column of the data set  for more close analysis of the data ..
#
#     3. Happiness Rank
#    It Shows the Rank of Happiness of the region through The rankings of national happiness are based on a Cantril ladder survey.It contains articles and rankings of national happiness, based on respondent ratings of their own lives..
#
#     4. Happiness Score
#
#  It Shows the rankings of national happiness are based on a Cantril ladder survey. Nationally representative samples of respondents are asked to think of a ladder, with the best possible life for them being a 10, and the worst possible life being a 0..
#
#     5. Standard Error
#
#   It shows the standard error (SE) of a statistic is the standard deviation of its sampling distribution or an estimate of that standard deviation.
#
#     6. Economy (GDP per Capita)
#
#   it shows Per capita gross domestic product (GDP) measures a country's economic output per person and is calculated by dividing the GDP of a country by its population.
#
#     7. Family
#
#   It Shows the family happiness index in the region of the country..
#
#     8. Health (Life Expectancy)
#
#    It Shows the Healthy life expectancy (HLE) is the expected number of remaining years of life spent in good health from a particular age, typically birth or age sixty-five, assuming current rates of mortality and morbidity..
#
#     9. Freedom
#
#    It Shows the index of the power or right to act, speak, or think as one wants.
#
#
#      10. 'Trust (Government Corruption)
#
#   It Shows the index of political corruption, interpersonal trust, political trust, legitimacy, perceptions of corruption and trust in political institutions..
#
#
#
#      11. Generosity
#
#    It shows the rating of the quality of being kind and generous.
#
#
#       12. Dystopia Residual
#
#    It Shows an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# It depicts that no null values are present in the Dataset

# %% [markdown]
# # Transforming Categorical Data For  Better Analysis

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

list1=['Country','Region']
for val in list1:
  df[val]=le.fit_transform(df[val].astype(str))


df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# We can see that the after transforming the categorical data into numereical value ..There is a huge variety of the info that can affect the analysis due to present of large variance ..
# so its better to drop the COUNTRY and REGION Columns

# %% [markdown]
# # EDA

# %% [markdown]
# Scatter Plot

# %%
import seaborn as sns
sns.scatterplot(x="Standard Error",y="Happiness Score",data=df)

# %% [markdown]
# We can see that the standard errors are densly distributed in between 0.03 to 0.07 for higher rate of happiness score

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Happiness Score",data=df)

# %% [markdown]
# We can see that the scatter plot is linearly distributed higher the Economy GDP per Captia More the Happiness Score showing direct Correlation

# %%
sns.scatterplot(x="Family",y="Happiness Score",data=df)

# %% [markdown]
# We can see that the family score is highly densed around 0.7 to 1.4 , The Higher the family Values results in High Happiness Score

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Happiness Score",data=df)

# %% [markdown]
# We can see that Healt is linearly distibuted between 0.25 to 1.0
# high the health score higher the happiness score

# %%
sns.scatterplot(x="Freedom",y="Happiness Score",data=df)

# %% [markdown]
# We can see that the Freddom is well dsitributed between 0.2 to 0.7 getting more dense when moving up showing that the higher freedom gives out high happiness score

# %%
sns.scatterplot(x="Trust (Government Corruption)",y="Happiness Score",data=df)

# %% [markdown]
# We can see  that the score are densly ditributed between 0 to 0.2 showing less the corruption higher the family happiness score

# %%
sns.scatterplot(x="Generosity",y="Happiness Score",data=df)

# %% [markdown]
# We can see that it is densly distributed between 0.05 to 0.5 and is unevenly distributed

# %%
sns.scatterplot(x="Dystopia Residual",y="Happiness Score",data=df)

# %% [markdown]
# we can see that it is more densly and equally distributed between 1.4 to 3.2 range

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# # Coorelation..

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Coorelation using Heat Map

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')

# %% [markdown]
# # Out Come of Coorelation

# %% [markdown]
# All the columns of the data is positively coorelated with the Happiness Score (except Standard Error)..
#
# 1. Generosity has 18 percent coorelation with the Happiness Score Column which can be considered as a Good bond.
#
# 2. Trust (Government Corruption) has 40 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# 3. Dystopia Residual has 53 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# 4. Freedom has 57 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# 5. Health (Life Expectancy) has 72 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# 6. Family has 74 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# 7. Economy (GDP per Capita) has 78 percent coorelation with the Happiness Score Column which can be considered as a strong bond.
#
# * Max Coorelation - Economy (GDP per Capita)
# * Min Coorelation - Generosity
# * Negatively Correlated - Standard Error

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# Describing Datasets

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')

# %% [markdown]
# # Out Come of Describe Datasets

# %% [markdown]
# From the above plotting we are determining mean Standard Deviation , minimum and maximum value of each column.
# It Helps further in data cleaning ..
#
# Total Numbers of rows in the Datasets are
# 1. 158 Rows
# 2. 12 Columns
#
# * Standard Error
#
#     * Mean_Value - 0.047885
#     * Max_Value -  0.13690
#     * Min_Value -  0.018480
#     * Std -        0.017146
#
# * Generosity
#
#     * Mean_Value - 0.237296
#     * Max_Value -0.795880
#     * Min_Value -0.0000
#     * Std -      0.126685
# * Trust (Government Corruption)
#
#     * Mean_Value - 0.143422
#     * Max_Value -0.551910
#     * Min_Value -0.00000
#     * Std -   0.120034
# * Dystopia Residual
#
#     * Mean_Value -2.098977
#     * Max_Value -3.602140
#     * Min_Value -0.328580
#     * Std -  0.553550
# * Freedom
#
#     * Mean_Value - 0.428615
#     * Max_Value -0.669730
#     * Min_Value -0.0000
#     * Std -   0.150963
# * Health (Life Expectancy)
#
#     * Mean_Value - 0.630259
#     * Max_Value -1.025250
#     * Min_Value -0.0000
#     * Std -       0.272369
# * Family
#
#     * Mean_Value - 0.991046
#     * Max_Value -1.402230
#     * Min_Value -0.000
#     * Std -      0.272369
# * Economy (GDP per Capita)
#
#     * Mean_Value - 0.846137
#     * Max_Value -1.690420
#     * Min_Value -0.0000
#     * Std -     0.403121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    int64
#  1   Region                         158 non-null    int64
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(3)
# ...

# %% [markdown]
# From the above code we can have Columns Datatypes and the memory used by the dataframe..

# %% [markdown]
# # Outliers Checking..

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.boxplot()

# %%
df.plot(kind='box',subplots=True, layout=(4,3))
# Out:
# Country                              AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Region                            AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# Happiness Rank                    AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# Happiness Score                     AxesSubplot(0.125,0.518913;0.227941x0.16413)
# Standard Error                   AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Economy (GDP per Capita)         AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# Family                              AxesSubplot(0.125,0.321957;0.227941x0.16413)
# Health (Life Expectancy)         AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# Freedom                          AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# Trust (Government Corruption)          AxesSubplot(0.125,0.125;0.227941x0.16413)
# Generosity                          AxesSubplot(0.398529,0.125;0.227941x0.16413)
# Dystopia Residual                   AxesSubplot(0.672059,0.125;0.227941x0.16413)
# ...

# %%
df['Economy (GDP per Capita)'].plot.box()

# %%
df['Happiness Score'].plot.box()

# %%
df['Family'].plot.box()

# %%
df['Health (Life Expectancy)'].plot.box()

# %%
df['Standard Error'].plot.box()

# %%
df['Dystopia Residual'].plot.box()

# %%
df['Generosity'].plot.box()

# %%
df['Freedom'].plot.box()

# %%
df['Trust (Government Corruption)'].plot.box()

# %% [markdown]
# From the above output we can see that the Columns can be categorized into three sections..
# 1. Max_Outliers
#    * Trust (Government Corruption)
#    * Standard Error
# 2. Min_Outliers
#   * Generosity
#   * Dystopia Residual
#   * Family
# 3. No_Outliers
#    * Freedom
#    * Health (Life Expectancy)
#    * Happiness Score
#    * Economy (GDP per Capita)

# %% [markdown]
# # Skewness..

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Outcome of the skewness :- Skewness Threshold is taken as +/- 0.5..
#
# Columns having Skewness are -
#   * Standard Error
#   * Family
#   * Trust (Government Corruption)
#   * Generosity

# %% [markdown]
# # Normal Distribution Curve

# %%
import seaborn as sns
sns.displot(df["Standard Error"])

# %% [markdown]
# The Data of the Column is Normal.
# Bt the curve is not Normal

# %%
sns.displot(df["Family"])

# %% [markdown]
# The Data of the Column is Normal.
# Bt the curve is not Normal

# %%
sns.displot(df["Trust (Government Corruption)"])

# %% [markdown]
# The Data of the Column is Normal.
# Bt the curve is not Normal

# %%
sns.displot(df["Generosity"])

# %% [markdown]
# The Data of the Column is Normal.
# Bt the curve is not Normal

# %% [markdown]
# # The Normal Distribution Shows that the Data is Skewwed..

# %% [markdown]
# # Data Cleaning.

# %%
df.corr()['Happiness Score']
# Out:
# Country                          0.083380
# Region                          -0.176791
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Here we are setting the Threshold of correlation as +/- 0.1.It is not standard.The Data set Demands it

# %%
df=df.drop(["Country","Region","Happiness Rank","Standard Error"],axis=1)
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %% [markdown]
# Removed Negatively Coorelated Columns and Non Numerical Columns..

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# IQR Proximity Rule
#
# Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 8)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157]), array([5, 6, 2, 5, 7, 2]))

# %%
len(np.where(z>3)[0])
# Out:
# 6

# %%
df.drop([27, 128, 147, 153, 155, 157],axis=0)
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df=df[(z<3).all(axis=1)]

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(158-152)/158*100
print(loss_percent,'%')
# Out:
# 3.79746835443038 %

# %% [markdown]
# # Re Arranging the columns for Further process with target at the last

# %% [markdown]
# checking whether how much outliers are presentin the dataset or not

# %%
column_to_move = df.pop("Happiness Score")
df.insert(7, "Happiness Score", column_to_move)
df
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  \
# ...

# %% [markdown]
# # Model Without Outliers is df and Model with Desired Outliers is df_new1

# %% [markdown]
# Dividing data in features and vectors:

# %%
# independent Column
x=df.iloc[:,:-1]
# target
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %%
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
x.shape
# Out:
# (152, 7)

# %%
y.shape
# Out:
# (152,)

# %% [markdown]
# # Transforming Data to remove Skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.49611068,  1.66761865,  1.48143363, ...,  1.82206989,
#          0.65595135,  0.74453432],
#        [ 1.19771756,  2.02101058,  1.52291872, ...,  0.35523025,
#          1.57166845,  1.10426166],
#        [ 1.27024568,  1.7401529 ,  1.06659878, ...,  1.95457488,
#          0.97742359,  0.69531125],
#        ...,
#        [-1.35114936, -2.09149024, -1.35026722, ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.4183337 , -2.01503265, -1.30696688, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.91827051, -1.91154624, -1.55177307, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.49611068,  1.66761865,  1.48143363, ...,  1.82206989,
#          0.65595135,  0.74453432],
#        [ 1.19771756,  2.02101058,  1.52291872, ...,  0.35523025,
#          1.57166845,  1.10426166],
#        [ 1.27024568,  1.7401529 ,  1.06659878, ...,  1.95457488,
#          0.97742359,  0.69531125],
#        ...,
#        [-1.35114936, -2.09149024, -1.35026722, ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.4183337 , -2.01503265, -1.30696688, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.91827051, -1.91154624, -1.55177307, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %% [markdown]
# # Since the Outcome is a Rating Value we will use Binary Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Importing ML Alogoritm Models

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Training And Splitting Data For Model Training

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (101, 7)

# %%
y_train.shape
# Out:
# (101,)

# %%
x_test.shape
# Out:
# (51, 7)

# %%
y_test.shape
# Out:
# (51,)

# %% [markdown]
# # Linear Regression Model

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 5.434169973092333

# %%
lr.coef_
# Out:
# array([0.39806471, 0.2437783 , 0.24765203, 0.15991733, 0.07300533,
#        0.09838273, 0.51463364])

# %%
lr.score(x_train,y_train)
# Out:
# 0.993205613416726

# %%
pred=lr.predict(x_test)
print("predicted result ",pred)
print('actual result',y_test)
# Out:
# predicted result  [5.43557607 3.71101535 4.88095579 5.09560271 4.03831971 3.86410528
#  6.65838803 7.33701689 7.05796513 6.96476633 4.07738713 4.53239751
#  4.68390199 6.86209693 5.40331072 7.3145812  5.72529202 6.48192254
#  4.44904227 4.651447   4.60167895 6.46893519 5.75209092 5.49527918
#  5.71470622 3.95622999 6.3418656  5.1537778  4.60166901 5.97460225
#  5.05906218 6.53903113 6.80678028 5.86316639 5.21121714 7.30394363
#  4.2574488  4.61818128 5.76820562 6.70790779 3.61599988 4.29693265
#  7.45061666 6.33103327 6.06624745 3.86325139 4.67506419 7.0267322
#  7.35161152 4.37796227 4.97751445]
# actual result 69     5.548
# 150    3.655
# 97     4.885
# 83     5.140
# 137    3.995
# 141    3.904
# 26     6.670
# 12     7.200
# 18     6.937
# 15     6.983
# 136    4.033
# 130    4.292
# 109    4.686
# 19     6.901
# 70     5.477
# 9      7.284
# 66     5.689
# 31     6.485
# 127    4.332
# 116    4.565
# 114    4.610
# 32     6.477
# 57     5.824
# 68     5.589
# 61     5.759
# ...

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,pred))
print('Mean Squared Error :',mean_squared_error(y_test,pred))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score :',r2_score(y_test,pred))
# Out:
# Error:
# Mean Absolute Error : 0.05596884885182659
# Mean Squared Error : 0.005089306524116502
# Root mean Squared Error 0.0713393756919452
# r2 score : 0.9960401565956831

# %% [markdown]
# # Decission Tree Model

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
predr=dtr.predict(x_test)
print("predicted result ",predr)
print('actual result',y_test)
# Out:
# predicted result  [5.399 4.077 4.642 4.739 3.781 4.252 5.813 7.406 7.119 6.269 4.715 4.369
#  3.989 6.853 5.007 7.364 5.429 6.168 4.642 5.36  4.507 6.123 6.123 6.123
#  5.332 3.781 5.948 5.855 4.55  5.889 5.007 6.574 5.833 5.709 4.694 5.975
#  4.194 4.512 5.889 5.987 3.845 4.739 7.286 5.709 5.332 5.098 5.192 6.94
#  5.948 4.55  4.507]
# actual result 69     5.548
# 150    3.655
# 97     4.885
# 83     5.140
# 137    3.995
# 141    3.904
# 26     6.670
# 12     7.200
# 18     6.937
# 15     6.983
# 136    4.033
# 130    4.292
# 109    4.686
# 19     6.901
# 70     5.477
# 9      7.284
# 66     5.689
# 31     6.485
# 127    4.332
# 116    4.565
# 114    4.610
# 32     6.477
# 57     5.824
# 68     5.589
# 61     5.759
# 140    3.931
# 37     6.298
# 87     5.102
# 113    4.633
# 43     6.003
# 86     5.123
# 30     6.505
# 22     6.810
# 52     5.878
# 76     5.286
# 11     7.226
# 129    4.297
# 115    4.571
# 56     5.828
# 28     6.575
# 151    3.587
# 126    4.350
# 4      7.427
# ...

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,predr))
print('Mean Squared Error :',mean_squared_error(y_test,predr))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,predr)))
print('r2 score :',r2_score(y_test,predr))
# Out:
# Error:
# Mean Absolute Error : 0.3993725490196079
# Mean Squared Error : 0.26585843137254905
# Root mean Squared Error 0.5156146151657739
# r2 score : 0.7931431814994924

# %% [markdown]
# # K- Nieghbour Regression Model

# %%
knr=KNeighborsRegressor(n_neighbors=5)
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 0.930784062969571

# %%
predknr=knr.predict(x_test)
print("predicted result ",predknr)
print('actual result',y_test)
# Out:
# predicted result  [5.6296 3.959  5.2476 5.4014 4.2692 4.217  6.3104 7.266  7.2236 6.5892
#  4.0338 4.5274 4.8214 7.179  5.3158 7.298  5.4518 7.18   4.978  4.4324
#  4.4216 6.2164 5.6814 5.1628 5.1336 4.3508 5.9592 5.1562 4.647  6.5758
#  4.9718 6.1088 6.0278 5.9282 5.1106 6.6626 4.6954 4.755  5.4224 6.4796
#  3.8164 4.7462 7.4154 6.1516 5.3014 4.6458 4.7966 7.2042 6.8738 4.3376
#  4.7982]
# actual result 69     5.548
# 150    3.655
# 97     4.885
# 83     5.140
# 137    3.995
# 141    3.904
# 26     6.670
# 12     7.200
# 18     6.937
# 15     6.983
# 136    4.033
# 130    4.292
# 109    4.686
# 19     6.901
# 70     5.477
# 9      7.284
# 66     5.689
# 31     6.485
# 127    4.332
# 116    4.565
# 114    4.610
# 32     6.477
# 57     5.824
# 68     5.589
# 61     5.759
# 140    3.931
# 37     6.298
# 87     5.102
# 113    4.633
# 43     6.003
# 86     5.123
# 30     6.505
# 22     6.810
# 52     5.878
# 76     5.286
# 11     7.226
# 129    4.297
# 115    4.571
# 56     5.828
# ...

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,predknr))
print('Mean Squared Error :',mean_squared_error(y_test,predknr))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,predknr)))
print('r2 score :',r2_score(y_test,predknr))
# Out:
# Error:
# Mean Absolute Error : 0.2909098039215687
# Mean Squared Error : 0.1257956125490196
# Root mean Squared Error 0.35467677193329084
# r2 score : 0.9021220427019356

# %% [markdown]
# # Support Vector Regression Model

# %% [markdown]
# KERNEL = RBF

# %%
svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# 0.9881015954125998

# %% [markdown]
# KERNEL = POLY

# %%
svp=SVR(kernel='poly')
svp.fit(x_train,y_train)
svp.score(x_train,y_train)
# Out:
# 0.9411407464197892

# %% [markdown]
# KERNEL = LINEAR

# %%
svl=SVR(kernel='poly')
svl.fit(x_train,y_train)
svl.score(x_train,y_train)
# Out:
# 0.9411407464197892

# %% [markdown]
# Since the Highest score is of KERNEL = RBF (0.98) we move forward with RBF as Kernel

# %%
predsvr=svr.predict(x_test)
print("predicted result ",predsvr)
print('actual result',y_test)
# Out:
# predicted result  [5.59977886 3.8581738  4.90698441 5.05854954 4.0688824  3.80827645
#  6.82564626 7.42681398 7.18853192 6.64610879 4.23492225 4.63720078
#  4.74202453 6.92995424 5.32175133 7.31335995 5.66039777 6.78053802
#  4.75385474 4.41740593 4.52745498 6.37316776 5.91646603 5.48885133
#  5.57224341 4.21217947 6.38143902 4.97207706 4.46206281 5.94022123
#  5.11468178 6.22427815 6.30506606 6.00657883 5.44553982 6.78781549
#  5.00947578 4.55524103 6.02422414 6.49443063 3.57468432 4.48160584
#  7.39755281 6.10934623 5.94095895 4.46357465 4.84189038 6.96628545
#  6.74134358 4.19525553 4.8706609 ]
# actual result 69     5.548
# 150    3.655
# 97     4.885
# 83     5.140
# 137    3.995
# 141    3.904
# 26     6.670
# 12     7.200
# 18     6.937
# 15     6.983
# 136    4.033
# 130    4.292
# 109    4.686
# 19     6.901
# 70     5.477
# 9      7.284
# 66     5.689
# 31     6.485
# 127    4.332
# 116    4.565
# 114    4.610
# 32     6.477
# 57     5.824
# 68     5.589
# 61     5.759
# ...

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,predsvr))
print('Mean Squared Error :',mean_squared_error(y_test,predsvr))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,predsvr)))
print('r2 score :',r2_score(y_test,predsvr))
# Out:
# Error:
# Mean Absolute Error : 0.17937336616456834
# Mean Squared Error : 0.05801644009717963
# Root mean Squared Error 0.24086602105149582
# r2 score : 0.9548590723368459

# %% [markdown]
# # Cross Validation for Linear Regression..

# %%
df.plot(kind='box',subplots=True, layout=(4,2))
# Out:
# Economy (GDP per Capita)             AxesSubplot(0.125,0.71587;0.352273x0.16413)
# Family                            AxesSubplot(0.547727,0.71587;0.352273x0.16413)
# Health (Life Expectancy)            AxesSubplot(0.125,0.518913;0.352273x0.16413)
# Freedom                          AxesSubplot(0.547727,0.518913;0.352273x0.16413)
# Trust (Government Corruption)       AxesSubplot(0.125,0.321957;0.352273x0.16413)
# Generosity                       AxesSubplot(0.547727,0.321957;0.352273x0.16413)
# Dystopia Residual                      AxesSubplot(0.125,0.125;0.352273x0.16413)
# Happiness Score                     AxesSubplot(0.547727,0.125;0.352273x0.16413)
# dtype: object

# %%
from sklearn.model_selection import cross_val_score
j=[lr,dtr,knr,svr]
for n in j:
  print('Cross_Validation_score of',n,'is')
  score=cross_val_score(n,x,y,cv=8)
  print(score)
  print(score.mean())
  print(score.std())
  print('\n')
# Out:
# Cross_Validation_score of LinearRegression() is
# [ 0.7381503   0.84920558  0.4038367   0.72507826 -0.08078488  0.6535013
#   0.34024382  0.6990415 ]
# 0.5410340735498631
# 0.2852872735716531
#
#
# Cross_Validation_score of DecisionTreeRegressor() is
# [ -7.03211309  -9.69125694 -21.61415797 -11.58165378 -36.86902726
#  -19.28836733 -26.74136404  -7.29725799]
# -17.514399802123002
# 9.939572501392826
#
#
# Cross_Validation_score of KNeighborsRegressor() is
# [-8.32192886 -4.49815438 -4.92071101 -3.17260173 -9.68757148 -7.53843663
#  -9.67908216 -9.01426183]
# -7.104093509863121
# 2.3885181168108556
#
#
# Cross_Validation_score of SVR() is
# [-11.47610597  -0.58730342  -0.02648895   0.66527814  -0.39336048
#   -0.15385565  -4.62673907  -4.72094851]
# -2.6649404877472582
# 3.8656571398977313

# %%
from sklearn.model_selection import KFold
j=[lr,dtr,knr,svr]
for n in j:
  print('K_Fold',n,'is')
  Kfold=KFold(5)
  score=cross_val_score(n,x,y,cv=Kfold)
  print(score)
  print(score.mean())
  print(score.std())
  print('\n')
# Out:
# K_Fold LinearRegression() is
# [0.87716411 0.81937077 0.7862294  0.72068022 0.81981768]
# 0.8046524376106919
# 0.051176749817678335
#
#
# K_Fold DecisionTreeRegressor() is
# [ -7.18955185 -12.93775203  -5.45362903  -9.48237533  -4.83055801]
# -7.978773251879782
# 2.9584716558314774
#
#
# K_Fold KNeighborsRegressor() is
# [-9.61285235 -3.75202606 -1.33424011 -3.3319773  -5.46104384]
# -4.698427931225576
# 2.786172065800598
#
#
# K_Fold SVR() is
# [-9.79748804  0.28686874  0.71600534 -0.04612624 -4.59440342]
# -2.6870287247321074
# 4.039697580779453

# %% [markdown]
# # Saving the Best Model

# %%
import joblib
joblib.dump(lr,'Lr_File_World_Happiness_Report.obj')
# Out:
# ['Lr_File_World_Happiness_Report.obj']

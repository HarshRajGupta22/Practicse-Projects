# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshRajGupta22/Practicse-Projects/blob/main/Titanic_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic

# %% [markdown]
# RMS Titanic was a British passenger liner, operated by the White Star Line, which sank in the North Atlantic Ocean on 15 April 1912 after striking an iceberg during her maiden voyage from Southampton, UK, to New York City. Of the estimated 2,224 passengers and crew aboard, more than 1,500 died, which made the sinking possibly one of the deadliest for a single ship up to that time. It remains to this day the deadliest peacetime sinking of a superliner or cruise ship. The disaster drew much public attention, provided foundational material for the disaster film genre, and has inspired many artistic works.
#
# RMS Titanic was the largest ship afloat at the time she entered service and the second of three Olympic-class ocean liners operated by the White Star Line. She was built by the Harland and Wolff shipyard in Belfast. Thomas Andrews, who was the chief naval architect of the shipyard at that time, died in the disaster.

# %% [markdown]
# # Data Description

# %% [markdown]
# The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster. Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.

# %% [markdown]
# # Loading the Data Set

# %%
import pandas as pd
import numpy as np
path ='https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Details About The Columns

# %% [markdown]
#     1. Passenger Id
#
# This Column shows the Passengers Unique Id alloted while Boarding on the ship.
#
#      2. Survived
#
# This Column shows whether the passenger survived or not During the disaster..
#
#       3. Pclass
#
# This Column shows the passengers class
#
#        4. Name
#
# This Column shows the passengers Unique Name
#
#       5. Sex
#
# This Column shows the passengers Unique Gender
#
#       6. Age
#
# This Column shows the Passengers Age
#
#       7. SibSp
#
# This Column shows the Siblings per person
#
#       8. Parch
#
# This Column shows the ratio of parents travelling with their child
#
#       9. Ticket
#
# This Column shows the Passengers Unique Booking Id OnBoard
#
#      10. Fare
#
# This Column shows the Price the passenger OnBoard paid to avail his or her Seat
#
#      11. Cabin
#
# This Column shows the Place where the passenger where assigned to stay
#
#      12. Embarked
#
# This Column shows the onboarding point of different Passenger

# %% [markdown]
# # Checking and Transforming the Data types of the Columns To Same DataTypes for  Better Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# We can see that the data consitsts various types of datatypes of columns within it..
#
#     1. Integer Type -
#
# * Passenger Id
# * Survived
# * Pclass
# * SibSp
# * Parch
#
#
#     2. Float -
#
# * Age
# * Fare
#
#       3. Object -
#
# * Name
# * Sex
# * Embarked
#
#       4. Alpha Numeric -
#
# * Ticket
# * Cabin

# %%
df.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# Changing the data types of the columns having Max unique 2 - 3 as per the requirement of the Dataset..

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

list1=['Embarked','Sex']
for val in list1:
  df[val]=le.fit_transform(df[val].astype(str))

# %% [markdown]
# Checking againg after Transformation of the DataTypes of the Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %% [markdown]
# # Checking for the Columns containing Null , Blank Or Empty Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# Checking the presence of NULL BLANK or EMPTY VALUES through HeatMap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# WE can seee that the columns -
# * Cabin ( highest )
# * Age
# * Embarked ( lowest )
#
# Contains Null , Blank and Empty Values
#
# Dropping the Cabin column as it contains 687 null values out of 891
#
# And for Age and Embarked Columns we use the ( Mean ) method..

# %% [markdown]
# # Dropping the Columns with more numbers of Null values and Uniqueness

# %%
df.describe(include=['O'])
# Out:
#                            Name  Ticket    Cabin
# count                       891     891      204
# unique                      891     681      147
# top     Braund, Mr. Owen Harris  347082  B96 B98
# freq                          1       7        4

# %%
df.drop(['Cabin','Name','Ticket','PassengerId'],axis=1,inplace=True)

# %% [markdown]
# Filling the age Column with Less null value with Mean value of the Column

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan,strategy="mean")
df['Age']=imp.fit_transform(df['Age'].values.reshape(-1,1))
df['Embarked']=imp.fit_transform(df['Embarked'].values.reshape(-1,1))

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500       2.0
# 1           1       1    0  38.000000      1      0  71.2833       0.0
# 2           1       3    0  26.000000      0      0   7.9250       2.0
# 3           1       1    0  35.000000      1      0  53.1000       2.0
# 4           0       3    1  35.000000      0      0   8.0500       2.0
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000       2.0
# 887         1       1    0  19.000000      0      0  30.0000       2.0
# 888         0       3    0  29.699118      1      2  23.4500       2.0
# 889         1       1    1  26.000000      0      0  30.0000       0.0
# 890         0       3    1  32.000000      0      0   7.7500       1.0
#
# [891 rows x 8 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# Histogram

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %% [markdown]
# Observations.
#
# * Infants (Age <=4) had high survival rate.
# * Oldest passengers (Age = 80) survived.
# * Large number of 15-25 year olds did not survive.
# * Most passengers are in 15-35 age range.

# %% [markdown]
# VoilinPlot

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Pclass', y = 'Survived', data = df, hue = 'Sex')
sns.violinplot(x = 'Pclass', y = 'Survived', data = df)

# %%
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# Observation -
# * Males had better survival rate in Pclass=3 when compared with Pclass=2 for C and Q ports.
# * Most passengers in Pclass=1 survived.
# * Pclass=3 had most passengers, however most did not survive.
# * Infant passengers in Pclass=2 and Pclass=3 mostly survived.

# %% [markdown]
# ScatterPlot

# %%
sns.scatterplot(x="Survived",y="Fare",data=df)

# %% [markdown]
# Observations -
#
# * Higher fare paying passengers had better survival
# * Fares varied significantly with few passengers(<1%) paying as high as $512..

# %% [markdown]
# VoilinPlot

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Sex', y = 'Survived', data = df, hue = 'Sex')
sns.violinplot(x = 'Sex', y = 'Survived', data = df)

# %%
df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Sex  Survived
# 0    0  0.742038
# 1    1  0.188908

# %% [markdown]
# Observation -
#
# * Female passengers had much better survival rate than males
# * male has total count of 65 % in total nos.

# %% [markdown]
# VoilinPlot

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Embarked', y = 'Survived', data = df, hue = 'Sex')
sns.violinplot(x = 'Embarked', y = 'Survived', data = df)

# %%
df[["Embarked", "Survived"]].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Embarked  Survived
# 3       3.0  1.000000
# 0       0.0  0.553571
# 1       1.0  0.389610
# 2       2.0  0.336957

# %% [markdown]
# Embarked takes three possible values. S port used by most passengers

# %% [markdown]
# VoilinPort

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Parch', y = 'Survived', data = df, hue = 'Sex')
sns.violinplot(x = 'Parch', y = 'Survived', data = df)

# %%
df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# Most passengers (> 75%) did not travel with parents or children.

# %% [markdown]
# VoilinPort

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'SibSp', y = 'Survived', data = df, hue = 'Sex')
sns.violinplot(x = 'SibSp', y = 'Survived', data = df)

# %%
df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %% [markdown]
# Nearly 30% of the passengers had siblings and/or spouse aboard.

# %% [markdown]
# Comparing all the Columns
#
# Histogram

# %%
df.hist(figsize=(20,10), grid=False, layout=(3, 3), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ab1a989d0>,
# ...
#       dtype=object)

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # Coorelation

# %%
df.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# Age      -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# SibSp    -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# Embarked -0.163517  0.157112  0.104057 -0.022239  0.066654  0.038322
#
#               Fare  Embarked
# Survived  0.257307 -0.163517
# Pclass   -0.549500  0.157112
# Sex      -0.182333  0.104057
# Age       0.091566 -0.022239
# SibSp     0.159651  0.066654
# Parch     0.216225  0.038322
# Fare      1.000000 -0.221226
# Embarked -0.221226  1.000000

# %%
df.corr()['Survived'].sort_values()
# Out:
# Sex        -0.543351
# Pclass     -0.338481
# Embarked   -0.163517
# Age        -0.069809
# SibSp      -0.035322
# Parch       0.081629
# Fare        0.257307
# Survived    1.000000
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')

# %% [markdown]
# OutCome of Coorelation --
#
# * Pclass has a Correlation of 34 percent with Survived which can be considered as a Good Bond..
#
# * Sex has a Correlation of 54 percent with Survived which can be considered as a Strong Bond..
#
# * Age has a Correlation of 0.7 percent with Survived which can be considered as a weak Bond..
#
# * SibSp has a Correlation of 0.4 percent with Survived which can be considered as a weak Bond..
#
# * Fare has a Correlation of 26 percent with Survived which can be considered as a Good Bond..
#
# * Parch has a Correlation of 0.8 percent with Survived which can be considered as a Good Bond..
#
# * Embarked has a Correlation of 16 percent with Survived which can be considered as a Good Bond..

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked
# count  891.000000  891.000000
# mean    32.204208    1.538721
# std     49.693429    0.794231
# min      0.000000    0.000000
# 25%      7.910400    1.000000
# 50%     14.454200    2.000000
# 75%     31.000000    2.000000
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    float64
# dtypes: float64(3), int64(5)
# memory usage: 55.8 KB

# %% [markdown]
# Out Come of Descriptive Statistics --
#
# From the above plotting we are determining mean Standard Deviation , minimum and maximum value of each column. It Helps further in data cleaning ..
#
# * Total Numbers of rows in the Datasets are : -
#    * 891 Rows
#    * 8 Columns
#
# * Pclass : -
#    * Mean_Value - 2.308642
#    * Std - 0.836071
#    * Min_Value - 1.000000
#    * Max_Value - 1.00000
#
#
# * Sex : -
#    * Mean_Value - 0.647587
#    * Std - 0.477910
#    * Min_Value - 0.00000
#    * Max_Value - 1.00000
#
# * Age : -
#    * Mean_Value - 0.523008
#    * Std - 13.002015
#    * Min_Value - 0.42000
#    * Max_Value - 80.00000
#
# * SibSp : -
#    * Mean_Value - 0.523008
#    * Std - 1.102743
#    * Min_Value - 0.00000
#    * Max_Value - 8.00000
#
# * Parch : -
#    * Mean_Value - 0.381594
#    * Std - 0.806057
#    * Min_Value - 0.00000
#    * Max_Value -   6.00000
#
# * Fare : -
#    * Mean_Value - 32.204208
#    * Std - 49.693429
#    * Min_Value - 0.00000
#    * Max_Value - 512.3292000
#
# * Embarked : -
#    * Mean_Value - 1.538721
#    * Std - 0.794231
#    * Min_Value - 0.00000
#    * Max_Value - 3.00000

# %%
df.insert(7, 'Survived', df.pop('Survived'))

# %% [markdown]
# # Checking Data To Remove Skewness

# %%
df.iloc[:,:-1]
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.000000      1      0   7.2500       2.0
# 1         1    0  38.000000      1      0  71.2833       0.0
# 2         3    0  26.000000      0      0   7.9250       2.0
# 3         1    0  35.000000      1      0  53.1000       2.0
# 4         3    1  35.000000      0      0   8.0500       2.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    1  27.000000      0      0  13.0000       2.0
# 887       1    0  19.000000      0      0  30.0000       2.0
# 888       3    0  29.699118      1      2  23.4500       2.0
# 889       1    1  26.000000      0      0  30.0000       0.0
# 890       3    1  32.000000      0      0   7.7500       1.0
#
# [891 rows x 7 columns]

# %%
df.iloc[:,:-1].skew()
# Out:
# Pclass     -0.630548
# Sex        -0.618921
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# Embarked   -1.246689
# dtype: float64

# %% [markdown]
# Removing Skewness Using Power Transform

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(df.iloc[:,:-1],method='yeo-johnson')

df.iloc[:,:-1]=pd.DataFrame(x_new,columns=df.iloc[:,:-1].columns)

# %%
df.iloc[:,:-1].skew()
# Out:
# Pclass     -0.441438
# Sex        -0.618921
# Age         0.064420
# SibSp       0.808608
# Parch       1.228795
# Fare       -0.040329
# Embarked   -0.861651
# dtype: float64

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(3,3), figsize=[20,8])
# Out:
# Pclass         AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Sex         AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Age         AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# SibSp          AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Parch       AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Fare        AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Embarked          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Survived       AxesSubplot(0.398529,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# # IQR Proximity Rule
# Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (891, 8)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 61, 179, 263, 271, 277, 302, 413, 466, 481, 597, 630, 633, 674,
#        732, 806, 815, 822, 829, 851]), array([6, 5, 5, 5, 5, 5, 5, 5, 5, 5, 2, 5, 5, 5, 5, 5, 5, 6, 2]))

# %%
len(np.where(z>3)[0])
# Out:
# 19

# %%
df.drop([61, 179, 263, 271, 277, 302, 413, 466, 481, 597, 630, 633, 674,
       732, 806, 815, 822, 829, 851],axis=0)
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare  Embarked  \
# 0    0.863973  0.737695 -0.556267  1.373636 -0.560253 -0.878820  0.588574
# 1   -1.459129 -1.355574  0.657269  1.373636 -0.560253  1.336651 -1.767348
# 2    0.863973 -1.355574 -0.241577 -0.679850 -0.560253 -0.790065  0.588574
# 3   -1.459129 -1.355574  0.437923  1.373636 -0.560253  1.067352  0.588574
# 4    0.863973  0.737695  0.437923 -0.679850 -0.560253 -0.774439  0.588574
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.592604  0.737695 -0.164262 -0.679850 -0.560253 -0.294907  0.588574
# 887 -1.459129 -1.355574 -0.798775 -0.679850 -0.560253  0.527906  0.588574
# 888  0.863973 -1.355574  0.042001  1.373636  1.846856  0.288885  0.588574
# 889 -1.459129  0.737695 -0.241577 -0.679850 -0.560253  0.527906 -1.767348
# 890  0.863973  0.737695  0.215254 -0.679850 -0.560253 -0.812349 -1.177409
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# ...

# %%
df=df[(z<3).all(axis=1)]

# %%
df
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare  Embarked  \
# 0    0.863973  0.737695 -0.556267  1.373636 -0.560253 -0.878820  0.588574
# 1   -1.459129 -1.355574  0.657269  1.373636 -0.560253  1.336651 -1.767348
# 2    0.863973 -1.355574 -0.241577 -0.679850 -0.560253 -0.790065  0.588574
# 3   -1.459129 -1.355574  0.437923  1.373636 -0.560253  1.067352  0.588574
# 4    0.863973  0.737695  0.437923 -0.679850 -0.560253 -0.774439  0.588574
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.592604  0.737695 -0.164262 -0.679850 -0.560253 -0.294907  0.588574
# 887 -1.459129 -1.355574 -0.798775 -0.679850 -0.560253  0.527906  0.588574
# 888  0.863973 -1.355574  0.042001  1.373636  1.846856  0.288885  0.588574
# 889 -1.459129  0.737695 -0.241577 -0.679850 -0.560253  0.527906 -1.767348
# 890  0.863973  0.737695  0.215254 -0.679850 -0.560253 -0.812349 -1.177409
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# ...

# %%
df.shape
# Out:
# (872, 8)

# %% [markdown]
# # Feature Engineering ( Variantion Inflation Factor )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.corr()
# Out:
#             Pclass       Sex       Age     SibSp     Parch      Fare  \
# Pclass    1.000000  0.140921 -0.311765 -0.070500 -0.037425 -0.733404
# Sex       0.140921  1.000000  0.083942 -0.194840 -0.245669 -0.245278
# Age      -0.311765  0.083942  1.000000 -0.176908 -0.288097  0.106664
# SibSp    -0.070500 -0.194840 -0.176908  1.000000  0.433138  0.410511
# Parch    -0.037425 -0.245669 -0.288097  0.433138  1.000000  0.382064
# Fare     -0.733404 -0.245278  0.106664  0.410511  0.382064  1.000000
# Embarked  0.101015  0.109852 -0.034223  0.012507  0.028496 -0.141330
# Survived -0.348932 -0.540459 -0.082532  0.098920  0.143280  0.322142
#
#           Embarked  Survived
# Pclass    0.101015 -0.348932
# Sex       0.109852 -0.540459
# Age      -0.034223 -0.082532
# SibSp     0.012507  0.098920
# Parch     0.028496  0.143280
# Fare     -0.141330  0.322142
# Embarked  1.000000 -0.157401
# Survived -0.157401  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(),cmap="Blues",annot=True)

# %%
# independent Column
x=df.iloc[:,:-1]
# target
y=df.iloc[:,-1]

# %%
x
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare  Embarked
# 0    0.863973  0.737695 -0.556267  1.373636 -0.560253 -0.878820  0.588574
# 1   -1.459129 -1.355574  0.657269  1.373636 -0.560253  1.336651 -1.767348
# 2    0.863973 -1.355574 -0.241577 -0.679850 -0.560253 -0.790065  0.588574
# 3   -1.459129 -1.355574  0.437923  1.373636 -0.560253  1.067352  0.588574
# 4    0.863973  0.737695  0.437923 -0.679850 -0.560253 -0.774439  0.588574
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.592604  0.737695 -0.164262 -0.679850 -0.560253 -0.294907  0.588574
# 887 -1.459129 -1.355574 -0.798775 -0.679850 -0.560253  0.527906  0.588574
# 888  0.863973 -1.355574  0.042001  1.373636  1.846856  0.288885  0.588574
# 889 -1.459129  0.737695 -0.241577 -0.679850 -0.560253  0.527906 -1.767348
# 890  0.863973  0.737695  0.215254 -0.679850 -0.560253 -0.812349 -1.177409
#
# [872 rows x 7 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 872, dtype: int64

# %%
def vif_calc():
  vif=pd.DataFrame()
  vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
  vif["features"]=x.columns
  print(vif)

# %%
vif_calc()
# Out:
#    VIF Factor  features
# 0    2.875021    Pclass
# 1    1.114247       Sex
# 2    1.243743       Age
# 3    1.483314     SibSp
# 4    1.566994     Parch
# 5    3.578234      Fare
# 6    1.046074  Embarked

# %% [markdown]
# Since all the Columns VIF values are below 10 so we dont Remove any Column

# %% [markdown]
# # Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.85342691,  0.74642003, -0.54569048, ..., -0.56827034,
#         -1.04864724,  0.61829219],
#        [-1.47503261, -1.33972825,  0.67737802, ..., -0.56827034,
#          1.43178085, -1.77030427],
#        [ 0.85342691, -1.33972825, -0.2285289 , ..., -0.56827034,
#         -0.94927748,  0.61829219],
#        ...,
#        [ 0.85342691, -1.33972825,  0.05727725, ...,  1.82122076,
#          0.25870896,  0.61829219],
#        [-1.47503261,  0.74642003, -0.2285289 , ..., -0.56827034,
#          0.52631486, -1.77030427],
#        [ 0.85342691,  0.74642003,  0.23189162, ..., -0.56827034,
#         -0.97422721, -1.17218294]])

# %% [markdown]
# # As the Output of the Dataset is having only two outputs 0 and 1 ..
#
# # We Use Classification Models for Building ML Algo.

# %% [markdown]
# Finding the Best Accuracy and Random State

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

maxAcc=0
maxRs=0

for i in range(1,200):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
  lr=LogisticRegression()
  lr.fit(x_train,y_train)
  predrf=lr.predict(x_test)
  acc=accuracy_score(y_test,predrf)
  if acc>maxAcc:
    maxAcc=acc
    maxRs=i

print("Best Accuracy is",maxAcc*100,"on Random State",maxRs)
# Out:
# Best Accuracy is 86.85714285714286 on Random State 194

# %% [markdown]
# # Creating Test train split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=194)

# %% [markdown]
# # Logistic Regression

# %%
Lr=LogisticRegression()
Lr.fit(x_train,y_train)
predlr=Lr.predict(x_test)
print("Accuracy",accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy 86.85714285714286
# [[99 14]
#  [ 9 53]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       113
#            1       0.79      0.85      0.82        62
#
#     accuracy                           0.87       175
#    macro avg       0.85      0.87      0.86       175
# weighted avg       0.87      0.87      0.87       175

# %% [markdown]
# # Decission Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtr=DecisionTreeClassifier()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
print("Accuracy",accuracy_score(y_test,preddtr)*100)
print(confusion_matrix(y_test,preddtr))
print(classification_report(y_test,preddtr))
# Out:
# Accuracy 80.57142857142857
# [[92 21]
#  [13 49]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       113
#            1       0.70      0.79      0.74        62
#
#     accuracy                           0.81       175
#    macro avg       0.79      0.80      0.79       175
# weighted avg       0.81      0.81      0.81       175

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)

ad_pred=svc.predict(x_test)

print("Accuracy",accuracy_score(y_test,ad_pred)*100)
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# Accuracy 86.85714285714286
# [[107   6]
#  [ 17  45]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90       113
#            1       0.88      0.73      0.80        62
#
#     accuracy                           0.87       175
#    macro avg       0.87      0.84      0.85       175
# weighted avg       0.87      0.87      0.87       175

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier


Rrf=RandomForestClassifier()
Rrf.fit(x_train,y_train)

Rrf_pred=Rrf.predict(x_test)

print("Accuracy",accuracy_score(y_test,Rrf_pred)*100)
print(confusion_matrix(y_test,Rrf_pred))
print(classification_report(y_test,Rrf_pred))
# Out:
# Accuracy 81.71428571428572
# [[97 16]
#  [16 46]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       113
#            1       0.74      0.74      0.74        62
#
#     accuracy                           0.82       175
#    macro avg       0.80      0.80      0.80       175
# weighted avg       0.82      0.82      0.82       175

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(Lr,x,y,cv=5)
print("Cross Score of Linear Regression Model :",scr.mean()*100)
# Out:
# Cross Score of Linear Regression Model : 79.47192118226602

# %%
scr=cross_val_score(dtr,x,y,cv=5)
print("Cross Score of Linear Regression Model :",scr.mean()*100)
# Out:
# Cross Score of Linear Regression Model : 77.18029556650248

# %%
scr=cross_val_score(svc,x,y,cv=5)
print("Cross Score of Linear Regression Model :",scr.mean()*100)
# Out:
# Cross Score of Linear Regression Model : 81.53694581280789

# %%
scr=cross_val_score(Rrf,x,y,cv=5)
print("Cross Score of Linear Regression Model :",scr.mean()*100)
# Out:
# Cross Score of Linear Regression Model : 80.96486042692939

# %% [markdown]
# Since Random forest Classifier Performing Better than all other So we Move forward with it

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# Creating Parameter List to pass in Grid SearchCV

parameters = {'max_features': ['auto','sqrt','log2'],
              'max_depth' : [4,5,6,7,8],
              'criterion' :['gini','entropy']}

# %%
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring="accuracy")
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt'}

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)
accuracy_score(y_test,gcv_pred)
# Out:
# 0.8571428571428571

# %% [markdown]
# # ROC AUC Plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %% [markdown]
# Final Accuracy is 85% and AUC Score is 91% which is Quite Good

# %% [markdown]
# # Saving the Best Model

# %%
import pickle
filename = 'Titanic.pkl'
pickle.dump(Rrf,open(filename,'wb'))

# %% [markdown]
# # ..SALARY..

# %% [markdown]
# A salary is a form of periodic payment from an employer to an employee, which may be specified in an employment contract. It is contrasted with piece wages, where each job, hour or other unit is paid separately, rather than on a periodic basis. From the point of view of running a business, salary can also be viewed as the cost of acquiring and retaining human resources for running operations, and is then termed personnel expense or salary expense. In accounting, salaries are recorded in payroll accounts.
#
# Salary is a fixed amount of money or compensation paid to an employee by an employer in return for work performed. Salary is commonly paid in fixed intervals, for example, monthly payments of one-twelfth of the annual salary.
#
# Salary is typically determined by comparing market pay rates for people performing similar work in similar industries in the same region. Salary is also determined by leveling the pay rates and salary ranges established by an individual employer. Salary is also affected by the number of people available to perform the specific job in the employer's employment locale

# %%
import pandas as pd
import numpy as np
path ='https://raw.githubusercontent.com/dsrscientist/dataset3/main/Salaries.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
df.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %% [markdown]
# # Details about the Columns

# %% [markdown]
#     1. Rank..
#
# This columns shows the diffrent Designation for which PayScale is decided.
#
#     2. Discipline..
#
# This column shows the branch of knowledge, typically one studied in higher education.
#
#     3. Yrs.Since.Phd
#
# This columns shows the shows the number of years a person already has its Phd.
#
#     4. Yrs.Service
#
# This Column shows the Years of Service means the total number of full years in which a Employee has been employed
#
#     5. Sex
#
# This Columns show the gender category of the employee..
#
#     6. Salary
#
# This Column shows the pay scale of the employee of the dataset

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %% [markdown]
# It shows that no null values are present in the Dataset

# %% [markdown]
# # Transforming Datatypes of The Dataset into same format .ie. Categorical to Numerical For better Analysis

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

list1=['rank','discipline','sex']
for val in list1:
  df[val]=le.fit_transform(df[val].astype(str))

# %%
df.head()
# Out:
#    rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2           1             19           18    1  139750
# 1     2           1             20           16    1  173200
# 2     1           1              4            3    1   79750
# 3     2           1             45           39    1  115000
# 4     2           1             40           41    1  141500

# %%
df.tail()
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 392     2           0             33           30    1  103106
# 393     2           0             31           19    1  150564
# 394     2           0             42           25    1  101738
# 395     2           0             25           15    1   95329
# 396     1           0              8            4    1   81035

# %% [markdown]
# # EDA

# %% [markdown]
# Scatter Plot

# %%
import seaborn as sns
sns.scatterplot(x="rank",y="salary",data=df)

# %% [markdown]
# We can see that the data is only concentrated in three positions which are ..
# 0. Indicating Values for ASSOCIATE PROFESSOR..
# 1. Indicating Values for ASSISTANT PROFESSOR..
# 2. Indicating Values for PROFESSOR..
#
#  We can also see that the no of Professors are the Max and the Min is of Asstnt Professor

# %%
sns.scatterplot(x="discipline",y="salary",data=df)

# %% [markdown]
# From the plot we can see that the data for both Disciplines - A (0) and B (1) are more densly distributed between 55000 to 175000 Range..

# %%
sns.scatterplot(x="yrs.since.phd",y="salary",data=df)

# %% [markdown]
# From the above plot we can see that the data is Linearly Coorelated and is more densly distributed betweeen the range of 2 to 45 with Gradient Ascend as no. of year increases

# %%
sns.scatterplot(x="yrs.service",y="salary",data=df)

# %% [markdown]
# From the above plot we can see that the Data is densly populated in the range of 0 to 30

# %%
sns.scatterplot(x="sex",y="salary",data=df)

# %% [markdown]
# From the above we can see that the Male (1) has the max points while Female (0) is only upto the range of 150000

# %%
sns.pairplot(df)

# %% [markdown]
# # Coorelation

# %%
df.corr()
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service       sex  \
# rank           1.000000   -0.086266       0.525500     0.447499  0.132492
# discipline    -0.086266    1.000000      -0.218087    -0.164599  0.003724
# yrs.since.phd  0.525500   -0.218087       1.000000     0.909649  0.148788
# yrs.service    0.447499   -0.164599       0.909649     1.000000  0.153740
# sex            0.132492    0.003724       0.148788     0.153740  1.000000
# salary         0.522207    0.156084       0.419231     0.334745  0.138610
#
#                  salary
# rank           0.522207
# discipline     0.156084
# yrs.since.phd  0.419231
# yrs.service    0.334745
# sex            0.138610
# salary         1.000000

# %%
df.corr()['salary'].sort_values()
# Out:
# sex              0.138610
# discipline       0.156084
# yrs.service      0.334745
# yrs.since.phd    0.419231
# rank             0.522207
# salary           1.000000
# Name: salary, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')

# %% [markdown]
# # Out Come of Correlation

# %% [markdown]
# All the Columns are Positively Coorelated with the Salary
#
# 1. Rank has a Correlation of 52 percent with Salary which can be considered as a Strong Bond..
#
# 2. Discipline has a Correlation of 16 percent with Salary which can be considered as a Good Bond..
#
# 3. Yrs_since_Phd has a Correlation of 42 percent with Salary which can be considered as a strong bond..
#
# 4. Yrs_Service has a Correlation of 33 percent with Salary which can be considered as a strong Bond..
#
# 5. Sex has a Correlation of 14 percent with Salary which can be considered as a Good Bond..
#
# * Max Correlation - Rank
# * Min Coorelation - Sex

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# Describing Datasets

# %%
df.describe()
# Out:
#              rank  discipline  yrs.since.phd  yrs.service         sex  \
# count  397.000000  397.000000     397.000000   397.000000  397.000000
# mean     1.508816    0.544081      22.314861    17.614610    0.901763
# std      0.757486    0.498682      12.887003    13.006024    0.298010
# min      0.000000    0.000000       1.000000     0.000000    0.000000
# 25%      1.000000    0.000000      12.000000     7.000000    1.000000
# 50%      2.000000    1.000000      21.000000    16.000000    1.000000
# 75%      2.000000    1.000000      32.000000    27.000000    1.000000
# max      2.000000    1.000000      56.000000    60.000000    1.000000
#
#               salary
# count     397.000000
# mean   113706.458438
# std     30289.038695
# min     57800.000000
# 25%     91000.000000
# 50%    107300.000000
# 75%    134185.000000
# max    231545.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    int64
#  1   discipline     397 non-null    int64
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    int64
#  5   salary         397 non-null    int64
# dtypes: int64(6)
# memory usage: 18.7 KB

# %% [markdown]
# # Out Come of Describe Datasets

# %% [markdown]
# From the above plotting we are determining mean Standard Deviation , minimum and maximum value of each column. It Helps further in data cleaning ..
#
# * Total Numbers of rows in the Datasets are : -
#    * 397 Rows
#    * 6 Columns
#
# * Rank : -
#    * Mean_Value - 1.508816
#    * Max_Value - 2.00000
#    * Min_Value - 0.00000
#    * Std - 0.757486
#
# * Discipline : -
#    * Mean_Value - 0.544081
#    * Max_Value - 1.00000
#    * Min_Value - 0.00000
#    * Std - 0.498682
#
# * Yrs.Since.Phd : -
#
#    * Mean_Value - 22.314861
#    * Max_Value - 56.000000
#    * Min_Value - 1.000000
#    * Std - 12.887003
#
# * Yrs.Service : -
#    * Mean_Value - 17.614610
#    * Max_Value - 60.000000
#    * Min_Value - 0.000000
#    * Std   - 13.006024
#
# * Sex : -
#    * Mean_Value - 0.901763
#    * Max_Value - 1.000000
#    * Min_Value - 0.000000
#    * Std - 0.298010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    int64
#  1   discipline     397 non-null    int64
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    int64
#  5   salary         397 non-null    int64
# dtypes: int64(6)
# memory usage: 18.7 KB

# %% [markdown]
# From the above code we can have Columns Datatypes and the memory used by the dataframe..

# %% [markdown]
# # Out Liers Checking

# %%
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(4,2))
# Out:
# rank                 AxesSubplot(0.125,0.71587;0.352273x0.16413)
# discipline        AxesSubplot(0.547727,0.71587;0.352273x0.16413)
# yrs.since.phd       AxesSubplot(0.125,0.518913;0.352273x0.16413)
# yrs.service      AxesSubplot(0.547727,0.518913;0.352273x0.16413)
# sex                 AxesSubplot(0.125,0.321957;0.352273x0.16413)
# salary           AxesSubplot(0.547727,0.321957;0.352273x0.16413)
# dtype: object

# %%
df['rank'].plot.box()

# %%
df['discipline'].plot.box()

# %%
df['yrs.since.phd'].plot.box()

# %%
df['yrs.service'].plot.box()

# %%
df['sex'].plot.box()

# %%
df['salary'].plot.box()

# %% [markdown]
# From the above analysis we can see that we have minimum outliers only in 2 columns that are Columns:-
# * Salary
# * Yrs.Service

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.300880
# yrs.service      0.650569
# sex             -2.709958
# salary           0.714568
# dtype: float64

# %% [markdown]
# Outcome of the skewness :- Skewness Threshold is taken as +/- 0.5..
#
# Columns having Skewness are -
#   * Yrs.Service
#   *  Sex
#   * Salary
#   * Rank

# %% [markdown]
# # Normal distribution Curve

# %%
sns.displot(df["rank"])

# %% [markdown]
# The Data of the Column is Normal. Bt the curve is not Normal

# %%
sns.displot(df["yrs.service"])

# %% [markdown]
# The Data of the Column is Normal. Bt the curve is not Normal

# %%
sns.displot(df["sex"])

# %% [markdown]
# The Data of the Column is Normal. Bt the curve is not Normal

# %%
sns.displot(df["salary"])

# %% [markdown]
# The Data of the Column is Normal. Bt the curve is not Normal

# %% [markdown]
# # The Normal distribution Shows that the data is Skewwed

# %% [markdown]
# # Data Cleaning

# %%
df.corr()['salary']
# Out:
# rank             0.522207
# discipline       0.156084
# yrs.since.phd    0.419231
# yrs.service      0.334745
# sex              0.138610
# salary           1.000000
# Name: salary, dtype: float64

# %% [markdown]
# Here we are setting the Threshold of correlation as +/- 0.1.It is not standard.The Data set Demands it

# %%
df=df.drop(["sex"],axis=1)
df
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  salary
# 0       2           1             19           18  139750
# 1       2           1             20           16  173200
# 2       1           1              4            3   79750
# 3       2           1             45           39  115000
# 4       2           1             40           41  141500
# ..    ...         ...            ...          ...     ...
# 392     2           0             33           30  103106
# 393     2           0             31           19  150564
# 394     2           0             42           25  101738
# 395     2           0             25           15   95329
# 396     1           0              8            4   81035
#
# [397 rows x 5 columns]

# %% [markdown]
# Removing the Least Correlated Column from the Dataset

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# IQR Proximity Rule
#
# Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (397, 5)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 43, 131, 330, 364]), array([4, 3, 3, 4]))

# %%
len(np.where(z>3)[0])
# Out:
# 4

# %%
df.drop([43, 131, 330, 364],axis=0)
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  salary
# 0       2           1             19           18  139750
# 1       2           1             20           16  173200
# 2       1           1              4            3   79750
# 3       2           1             45           39  115000
# 4       2           1             40           41  141500
# ..    ...         ...            ...          ...     ...
# 392     2           0             33           30  103106
# 393     2           0             31           19  150564
# 394     2           0             42           25  101738
# 395     2           0             25           15   95329
# 396     1           0              8            4   81035
#
# [393 rows x 5 columns]

# %%
df=df[(z<3).all(axis=1)]

# %% [markdown]
# # Training the Model without Outliers

# %%
# independent Column
x=df.iloc[:,:-1]
# target
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    rank  discipline  yrs.since.phd  yrs.service
# 0     2           1             19           18
# 1     2           1             20           16
# 2     1           1              4            3
# 3     2           1             45           39
# 4     2           1             40           41

# %%
y.head()
# Out:
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# Name: salary, dtype: int64

# %%
x.shape
# Out:
# (393, 4)

# %%
y.shape
# Out:
# (393,)

# %% [markdown]
# # Transforming Data To Remove Skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.69481738,  0.91457564, -0.11344983,  0.26888583],
#        [ 0.69481738,  0.91457564, -0.03455335,  0.1209006 ],
#        [-1.0753989 ,  0.91457564, -1.6242611 , -1.28449532],
#        ...,
#        [ 0.69481738, -1.09340328,  1.42772852,  0.72581897],
#        [ 0.69481738, -1.09340328,  0.33874878,  0.04312953],
#        [-1.0753989 , -1.09340328, -1.12908354, -1.11979784]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.69481738,  0.91457564, -0.11344983,  0.26888583],
#        [ 0.69481738,  0.91457564, -0.03455335,  0.1209006 ],
#        [-1.0753989 ,  0.91457564, -1.6242611 , -1.28449532],
#        ...,
#        [ 0.69481738, -1.09340328,  1.42772852,  0.72581897],
#        [ 0.69481738, -1.09340328,  0.33874878,  0.04312953],
#        [-1.0753989 , -1.09340328, -1.12908354, -1.11979784]])

# %% [markdown]
# # Since the Outcome is a Salary Value we will use Binary Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Importing ML Alogoritm Models

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Training And Splitting Data For Model Training

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=44)

# %%
x_train.shape
# Out:
# (263, 4)

# %%
y_train.shape
# Out:
# (263,)

# %%
x_test.shape
# Out:
# (130, 4)

# %%
y_test.shape
# Out:
# (130,)

# %% [markdown]
# # Linear Regression Model

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 112839.40179016031

# %%
lr.coef_
# Out:
# array([14241.76782147,  6978.54812637, 12180.82188548, -7689.75781011])

# %%
lr.score(x_train,y_train)
# Out:
# 0.4204152832349748

# %%
pred=lr.predict(x_test)
print("predicted result ",pred)
print('actual result',y_test)
# Out:
# predicted result  [ 98660.49846998 122745.45437792 120017.14230109 120930.49965717
#  122307.0337387   77745.00230575 124243.98751129 131140.39778103
#  118336.03096196 141249.75566852 122281.53730404 135300.57866925
#   86017.74530811 137618.31210136  78333.32547506 124686.63821673
#  129796.59369355 111851.62230033  92202.63136082 125557.83502642
#  127662.10613541 114320.75932589  76603.54497983 137307.32575591
#   89095.41832989  94508.89457507  84616.89768736 132369.680152
#  124686.63821673 134015.16272706 126832.20880557 112398.73140624
#  131497.28335539 115749.42364366  81440.04745128 121644.54284425
#  110889.92445722  95464.47407832  92732.36935098 112615.90718697
#   89095.41832989 117636.3319366  123746.70809025 126913.99697659
#  114044.86518654  97840.24950919 103280.71639322 129286.27214485
#  131497.28335539 115749.42364366 120903.42560044 122718.55229045
#  117195.03672099 112027.33528087 122381.75320698 124596.81100116
#   88331.77638321 124243.98751129 125966.20603751 132744.03844889
#   93998.85310638 120204.44039221 128861.24570673 125124.51988468
#  137464.2477249   92460.872488   128544.4358103  119444.32080582
#  133460.71782807 120568.21601971 130632.67056955 118731.26095157
#  124993.78423092 109508.27666024  83370.02953593 131497.28335539
#  118197.88445429 135247.94813582  79931.65764421 125557.83502642
#  101325.00065764  83182.10000071 132911.82264386  88431.93372796
#  137094.85967498 125503.54142861 131649.10943393 111001.6015143
#  116219.1556867   99823.79629221 122986.96342332  80707.2845485
#   91164.94885446  86130.44614241  99671.8736059  134237.78002956
#  120348.29378725 136090.61887345  89095.41832989 100114.91176059
#   81440.04745128 132061.09717184 126994.33475381 120182.35511245
#   83236.26919684 123684.11387603 128880.23089264  86017.74530811
#  134514.34195791 113480.76201666 120929.04159763  83912.34531677
#  119239.91181061  73439.76549743 117752.36109541 125124.51988468
#  125838.40105056  95452.82494861 120002.38522973 128041.13815844
#  137730.28588197  90935.54785796 128477.58504791  89423.02096495
#  132369.680152    95708.97864197  87829.41909045 125707.40016355
#  118110.83446404  81440.04745128]
# actual result 79      84240
# 159    137167
# 301    127100
# 295     97150
# 304    144050
#         ...
# 55      83900
# 89     107008
# 356     88709
# 291    168500
# 112     72500
# Name: salary, Length: 130, dtype: int64

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,pred))
print('Mean Squared Error :',mean_squared_error(y_test,pred))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score :',r2_score(y_test,pred))
# Out:
# Error:
# Mean Absolute Error : 17769.8453859199
# Mean Squared Error : 498902871.6431691
# Root mean Squared Error 22336.13376668328
# r2 score : 0.42061352056465995

# %% [markdown]
# # Decission Tree Model

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 0.962970523175513

# %%
predr=dtr.predict(x_test)
print("predicted result ",predr)
print('actual result',y_test)
# Out:
# predicted result  [ 88825.   150917.    81700.   127257.5   67559.    74830.   111512.
#  101000.   125192.    57800.   204000.   146856.    78500.   142023.
#   83850.   130925.   107500.    93000.    90971.   121466.5  140096.
#  113068.    74830.   165000.   113600.   105350.    97000.   140310.
#  130925.   145098.   134778.    96938.   181257.   115800.    72750.
#   67559.   104350.    80225.    92350.   126882.   113600.   134690.
#  194800.   168635.   148800.    95611.    79858.   189409.   181257.
#  115800.   101036.   109954.   103700.   148800.   131950.   130664.
#   70700.   111512.    57800.   140310.    83558.25 127257.5  117704.
#  130664.   145098.    98510.   107986.   106294.   175000.   101036.
#  181257.   102600.    57800.    79858.    77517.5  181257.   121200.
#  161101.   100102.   121466.5   92000.    71350.   161101.    70700.
#   96545.   166605.   162150.    88175.   109646.    86250.    67559.
#   74000.    70768.   100938.    92000.   165000.   131950.   101299.
#  113600.    79858.    72750.   162150.   166605.   146800.    72750.
#  130925.   119015.    78500.   180000.   115435.   107550.   108413.
#   92050.    70000.   118021.5  130664.   183800.    75243.   151292.
#  156938.   145098.    71065.   156938.   103750.   140310.   109650.
#  113600.    77202.   102914.    72750.  ]
# actual result 79      84240
# 159    137167
# 301    127100
# 295     97150
# 304    144050
#         ...
# 55      83900
# 89     107008
# 356     88709
# 291    168500
# 112     72500
# Name: salary, Length: 130, dtype: int64

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,predr))
print('Mean Squared Error :',mean_squared_error(y_test,predr))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,predr)))
print('r2 score :',r2_score(y_test,predr))
# Out:
# Error:
# Mean Absolute Error : 23674.048076923078
# Mean Squared Error : 1021750298.5081731
# Root mean Squared Error 31964.829086171776
# r2 score : -0.18658027837143165

# %% [markdown]
# # K- Nieghbour Regression Model

# %%
knr=KNeighborsRegressor(n_neighbors=5)
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
# Out:
# 0.6273020838576082

# %%
predknr=knr.predict(x_test)
print("predicted result ",predknr)
print('actual result',y_test)
# Out:
# predicted result  [ 83127.2 141054.2 100745.8 126444.8 102790.6  88830.6 135919.  148814.
#  115670.4 118123.  117767.8 118123.   76267.  124101.6  89180.8 121765.2
#  117704.4 104917.   84219.2 127340.8 135748.  104448.8  88830.6 142365.6
#   98955.2  99812.4 102466.4 127161.2 121765.2 144165.8 130551.2 101749.8
#  150877.8 126635.8  73700.  102790.6 112972.   78924.4  89830.  122978.6
#   98955.2 113857.4 121908.2 145216.  112673.6 101235.   79370.2 153674.2
#  150877.8 126635.8 127260.2 109584.2 108730.  114265.  124363.8 127089.4
#   73160.  135919.   94143.4 132623.   83322.4 116774.8 147470.2 124199.4
#  125163.  100862.4 127047.2 110750.4 125027.  110130.6 146397.8 117255.8
#   94143.4  88386.6  76267.  150877.8 128880.6 146254.   89000.4 127340.8
#   83770.   75247.  155391.6  76277.  132795.6 154320.8 155079.6 117039.2
#  114233.6 106144.2 102790.6  78907.   85095.8  96422.8  85404.  140614.6
#  113246.  101041.8  98955.2  79370.2  73700.  155079.6 157935.  110168.8
#   74000.  127922.2 138485.   76267.  122915.2 112972.  102790.6  85278.6
#  110750.4  78174.4 128480.6 124199.4 133096.6  85076.8 119969.6 134060.
#  157034.6 100473.8 134060.   97236.4 127161.2 104253.   98928.2 102790.6
#  108995.4  73700. ]
# actual result 79      84240
# 159    137167
# 301    127100
# 295     97150
# 304    144050
#         ...
# 55      83900
# 89     107008
# 356     88709
# 291    168500
# 112     72500
# Name: salary, Length: 130, dtype: int64

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,predknr))
print('Mean Squared Error :',mean_squared_error(y_test,predknr))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,predknr)))
print('r2 score :',r2_score(y_test,predknr))
# Out:
# Error:
# Mean Absolute Error : 16697.40307692308
# Mean Squared Error : 525421575.7815385
# Root mean Squared Error 22922.076166471885
# r2 score : 0.38981678736624603

# %% [markdown]
# # Support Vector Regression Model

# %% [markdown]
# KERNEL = RBF

# %%
svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# -0.028991197006219993

# %% [markdown]
# KERNEL = POLY

# %%
svp=SVR(kernel='poly')
svp.fit(x_train,y_train)
svp.score(x_train,y_train)
# Out:
# -0.02865331006606575

# %% [markdown]
# KERNEL = LINEAR

# %%
svl=SVR(kernel='poly')
svl.fit(x_train,y_train)
svl.score(x_train,y_train)
# Out:
# -0.02865331006606575

# %% [markdown]
# Since the model score of all the Kernel of the model are in negative we dont move further with this model

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
j=[lr,dtr,knr,svr]
for n in j:
  print('Cross_Validation_score of',n,'is')
  score=cross_val_score(n,x,y,cv=6)
  print(score)
  print(score.mean())
  print(score.std())
  print('\n')
# Out:
# Cross_Validation_score of LinearRegression() is
# [0.32068983 0.51823966 0.41472994 0.40814311 0.24836014 0.36247348]
# 0.3787726925956689
# 0.08391791475094837
#
#
# Cross_Validation_score of DecisionTreeRegressor() is
# [-0.03199936  0.23355913  0.25157629 -0.11108434  0.0355575  -0.49990353]
# -0.020382386560522065
# 0.25162121469832155
#
#
# Cross_Validation_score of KNeighborsRegressor() is
# [0.29227448 0.44207119 0.46605782 0.37994063 0.31273318 0.27750698]
# 0.3617640482651856
# 0.07301700307835618
#
#
# Cross_Validation_score of SVR() is
# [-0.00119103 -0.00313292 -0.1245667  -0.01696764 -0.05204068 -0.22520958]
# -0.07051809070577113
# 0.08104193887334998

# %%
from sklearn.model_selection import KFold
j=[lr,dtr,knr,svr]
for n in j:
  print('K_Fold',n,'is')
  Kfold=KFold(5)
  score=cross_val_score(n,x,y,cv=Kfold)
  print(score)
  print(score.mean())
  print(score.std())
  print('\n')
# Out:
# K_Fold LinearRegression() is
# [0.24849052 0.57491121 0.41012385 0.26059421 0.31281385]
# 0.3613867278369952
# 0.12102232853857721
#
#
# K_Fold DecisionTreeRegressor() is
# [-0.32289026  0.27167189  0.01974122 -0.12949218 -0.58857454]
# -0.14990877666265626
# 0.29301142066722624
#
#
# K_Fold KNeighborsRegressor() is
# [0.12378939 0.61331952 0.39851353 0.26790525 0.28513138]
# 0.3377318131688729
# 0.16312996048101194
#
#
# K_Fold SVR() is
# [ 0.00158844 -0.00698975 -0.12816237 -0.00413057 -0.2510532 ]
# -0.07774949026169635
# 0.09929433853649434

# %% [markdown]
# # Saving The Best Model

# %%
import joblib
joblib.dump(knr,'Knr_File_Salary_Report.obj')
# Out:
# ['Knr_File_Salary_Report.obj']
